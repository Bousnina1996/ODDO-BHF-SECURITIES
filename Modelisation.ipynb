# %%
# Importation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
GeneriqueComptes = pd.read_table("GC.txt",sep=",")
GeneriqueComptesNew=GeneriqueComptes
# Out:
# C:\Users\iheb_\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.

# %%
GeneriqueComptes;

# %%
GeneriqueComptes;

# %%
GeneriqueComptesNew;

# %%
GeneriqueComptesNew["GCO_CodToleranceRisqueMif2"].unique()
# Out:
# array(['Non-Risqué', 'Risqué'], dtype=object)

# %%
GeneriqueComptes['GCO_CodToleranceRisqueMif2'] = np.where(
    GeneriqueComptes['GCO_CodToleranceRisqueMif2']>=5, 'Risqué', 'Non-Risqué')

# %%
dataCible=GeneriqueComptesNew.iloc[:,8]

# %%
dataSansCible
# Out:
#        GCO_IsOuvert  GCO_IsAsv  GCO_IsAssureur  GCO_IsPea  GCO_IsPeaPme  \
# 0                 1          0               1          0           0.0
# 1                 1          0               1          0           0.0
# 2                 1          0               1          0           0.0
# 3                 1          0               1          0           0.0
# 4                 1          0               1          0           0.0
# 5                 1          0               1          0           0.0
# 6                 1          0               1          0           0.0
# 7                 1          0               1          0           0.0
# 8                 1          0               1          0           0.0
# 9                 1          0               1          0           0.0
# 10                1          0               1          0           0.0
# 11                1          0               1          0           0.0
# ...

# %%
dataSansCible.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
GeneriqueComptesNew.head(1)
# Out:
#    GCO_IsOuvert  GCO_IsAsv  GCO_IsAssureur  GCO_IsPea  GCO_IsPeaPme  \
# 0             1          0               1          0           0.0
#
#    GCO_CodCapaciteSupportPertesMif2  GCO_CodProfilInvestissementMif2  \
# 0                               1.0                              1.0
#
#   GCO_CodToleranceRisqueMif2  GCO_CodHorizonPlacementMif2  \
# 0                 Non-Risqué                          2.0
#
#    GCO_CodObjectifPlacementMif2  GCO_CodProfilRisqueMif2  GCO_IsNanti
# 0                           1.0                      1.0            0

# %%
dataSansCible=GeneriqueComptesNew
GeneriqueComptesNew.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
dataCible
# Out:
# Index(['Unnamed: 0', 'GCO_IsOuvert', 'GCO_IsAsv', 'GCO_IsAssureur',
#        'GCO_IsPea', 'GCO_IsPeaPme', 'GCO_CodCapaciteSupportPertesMif2',
#        'GCO_CodProfilInvestissementMif2', 'GCO_CodToleranceRisqueMif2',
#        'GCO_CodHorizonPlacementMif2', 'GCO_CodObjectifPlacementMif2',
#        'GCO_CodProfilRisqueMif2', 'GCO_IsNanti'],
#       dtype='object')

# %%
data1=dataSansCible
y1=dataCible

# %%
GeneriqueComptesNew;

# %%
sns.countplot(GeneriqueComptesNew['GCO_CodToleranceRisqueMif2'],label="Count")
plt.show()

# %%
y= pd.factorize(dataCible)[0]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataSansCible, y,test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
error = []
# Calculer l'erreur pour k entre 1 et 40 
#Pour chaque itération, l'erreur moyenne pour les valeurs prédites 
#de l'ensemble de test est calculée et sauvegardée ds la liste Erreur.
for i in range(1, 40):
    knn = KNeighborsClassifier(i)
    knn_model = knn.fit(X_train, y_train)
    pred_i = knn_model.predict(X_test)
    error.append(np.mean(pred_i != y_test))
plt.figure(figsize=(12, 6))
plt.plot(range(1, 40), error, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10)
plt.title('Taux Erreur pour les differentes valeurs de k')
plt.xlabel('K ')
plt.ylabel('Erreur')
# Out:
# Text(0, 0.5, 'Erreur')

# %%
knn = KNeighborsClassifier(2)
knn_model = knn.fit(X_train, y_train)
y_pred_knn = knn_model.predict(X_test)

# %%
print('Accuracy of K-NN classifier on training set: {:.2f}'
      .format(knn.score(X_train, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(knn.score(X_test, y_test)))
# Out:
# Accuracy of K-NN classifier on training set: 0.99
# Accuracy of K-NN classifier on test set: 0.99

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred_knn))
# Out:
# [[10839    18]
#  [  123  1152]]

# %% [markdown]
# # Random Forest

# %%
#random forest kima arbre decisionnel ama tkharajlek ahsen arbre fil 
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc_model = rfc.fit(X_train, y_train)
y_pred_rfc = rfc_model.predict(X_test)
# Out:
# C:\Users\iheb_\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print('Accuracy of Random Forest classifier on training set: {:.2f}'
     .format(rfc.score(X_train, y_train)))
print('Accuracy of Random Forest classifier on test set: {:.2f}'
     .format(rfc.score(X_test, y_test)))
# Out:
# Accuracy of Random Forest classifier on training set: 0.99
# Accuracy of Random Forest classifier on test set: 0.99

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred_rfc))
# Out:
# [[10807    50]
#  [   87  1188]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     10857
#            1       0.96      0.93      0.95      1275
#
#     accuracy                           0.99     12132
#    macro avg       0.98      0.96      0.97     12132
# weighted avg       0.99      0.99      0.99     12132

# %%
train_X = X_train
train_y = y_train
test_X = X_test
test_y = y_test

# %% [markdown]
# # SGD

# %%
from sklearn.linear_model import SGDClassifier

sgd = SGDClassifier()
sgd.fit(train_X, train_y)
predictions3 = sgd.predict(test_X)
acc_sgd = accuracy_score(test_y, predictions3)
acc_sgd
# Out:
# 0.9884602703593801

# %%
from sklearn.linear_model import Perceptron

perceptron = Perceptron()
perceptron.fit(train_X, train_y)
predictions1 = perceptron.predict(test_X)
acc_perceptron = accuracy_score(test_y, predictions1)
acc_perceptron
# Out:
# 0.9521925486317178

# %%
from sklearn.naive_bayes import GaussianNB

gaussian = GaussianNB()
gaussian.fit(train_X, train_y)
predictions2 = gaussian.predict(test_X)
acc_gaussian = accuracy_score(test_y, predictions2)
acc_gaussian
# Out:
# 0.9297725024727992

# %%
from sklearn.svm import SVC, LinearSVC
svc = SVC(probability=True)
svc.fit(train_X, train_y)
predictions_svm = svc.predict(test_X)
acc_svc = accuracy_score(test_y, predictions_svm)
acc_svc
# Out:
# C:\Users\iheb_\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.9884602703593801

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %%
#KNN Acc
acc_svm = accuracy_score(y_test, predictions_svm)
acc_svm
# Out:
# 0.9884602703593801

# %%
#Random Forest
acc_rfc = accuracy_score(y_test, y_pred_rfc)
acc_rfc
# Out:
# 0.9890372568414112

# %%
#SVM
acc_knn = accuracy_score(y_test, y_pred_knn)
acc_knn
# Out:
# 0.98837784371909

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC, LinearSVC
svc = SVC(probability=True)
svc.fit(X_train, y_train)
predictions_svm = svc.predict(X_test)
acc_svc = accuracy_score(y_test, predictions_svm)
acc_svc

# %%
# Out:
# C:\Users\iheb_\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.9884602703593801

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN',
              'Random Forest', 'Naive Bayes', 'Perceptron', 
              'Stochastic Gradient Decent',
              ],
    'Score': [acc_svc, acc_knn, 
              acc_rfc, acc_gaussian, acc_perceptron, 
              acc_sgd, ]})
models.sort_values(by="Score",ascending=False)
# Out:
#                         Model     Score
# 2               Random Forest  0.989037
# 0     Support Vector Machines  0.988460
# 5  Stochastic Gradient Decent  0.988460
# 1                         KNN  0.988378
# 4                  Perceptron  0.952193
# 3                 Naive Bayes  0.929773

# %% [markdown]
# # Tableau Comparatif

# %%
models = pd.DataFrame({
    'Model': ['KNN',
              'Random Forest',
              'Support Vector Machine'],
    'Score': [acc_knn, acc_rfc, 
              acc_svm, ]})
models.sort_values(by="Score",ascending=False)
# Out:
#                     Model     Score
# 1           Random Forest  0.989037
# 2  Support Vector Machine  0.988460
# 0                     KNN  0.988378

# %%
dataSansCible
# Out:
#        GCO_IsOuvert  GCO_IsAsv  GCO_IsAssureur  GCO_IsPea  GCO_IsPeaPme  \
# 0                 1          0               1          0           0.0
# 1                 1          0               1          0           0.0
# 2                 1          0               1          0           0.0
# 3                 1          0               1          0           0.0
# 4                 1          0               1          0           0.0
# 5                 1          0               1          0           0.0
# 6                 1          0               1          0           0.0
# 7                 1          0               1          0           0.0
# 8                 1          0               1          0           0.0
# 9                 1          0               1          0           0.0
# 10                1          0               1          0           0.0
# 11                1          0               1          0           0.0
# ...

# %% [markdown]
# # ROC

# %%
# %matplotlib inline

from sklearn.metrics import roc_curve, auc

# %%
fpr1, tpr1, threshold1 = roc_curve(y_test, predictions_svm) 
roc_auc1 = auc(fpr1, tpr1)
fpr2, tpr2, threshold2 = roc_curve(y_test, y_pred_rfc) 
roc_auc2 = auc(fpr2, tpr2)
fpr3, tpr3, threshold3 = roc_curve(y_test, y_pred_knn)
roc_auc3 = auc(fpr3, tpr3)
fpr4, tpr4, threshold4 = roc_curve(y_test, predictions1) 
roc_auc4 = auc(fpr4, tpr4)
fpr5, tpr5, threshold5 = roc_curve(y_test, predictions2) 
roc_auc5 = auc(fpr5, tpr5)
fpr6, tpr6, threshold6 = roc_curve(y_test, predictions3)
roc_auc6 = auc(fpr6, tpr6)

# %%
plt.figure() 
plt.plot(fpr1, tpr1, color='blue', lw=2, label='Support Vector Machine (area = %0.2f)'% roc_auc1)
plt.plot(fpr2, tpr2, color='yellow', lw=2, label='Random Forest ROC curve (area = %0.2f)'% roc_auc2)
plt.plot(fpr3, tpr3, color='green', lw=2, label='kNN ROC curve (area = %0.2f)'% roc_auc3)
plt.plot(fpr4, tpr4, color='black', lw=2, label='Logistic Regression (area = %0.2f)'% roc_auc4)
plt.plot(fpr5, tpr5, color='purple', lw=2, label='Naive Bayes (area = %0.2f)'% roc_auc5)
plt.plot(fpr6, tpr6, color='red', lw=2, label='Perceptron (area = %0.2f)'% roc_auc6)
plt.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--') 
plt.xlim([0.0, 1.0]) 
plt.ylim([0.0, 1.05]) 
plt.xlabel('False Positive Rate') 
plt.ylabel('True Positive Rate') 
plt.title('Classifiers ROC curves') 
plt.legend(loc = "lower right")
plt.show()

# %% [markdown]
# # Application

# %%
# Out:
# 0,a, a 7
#  User
# 0,a,  has been registered successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-2d73ca1cfb21> in <module>
#      54
#      55 # On démarre la boucle Tkinter qui s'interompt quand on ferme la fenêtre
# ---> 56 fenetre.mainloop()
#
# ~\Anaconda3\lib\tkinter\__init__.py in mainloop(self, n)
#    1281     def mainloop(self, n=0):
#    1282         """Call the mainloop of Tk."""
# -> 1283         self.tk.mainloop(n)
#    1284     def quit(self):
#    1285         """Quit the Tcl interpreter. All widgets will be destroyed."""
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-192afa5ff3dd> in <module>
# ----> 1 new_new = pd.read_table("user.txt",sep=",")
#
# NameError: name 'pd' is not defined

# %%
new_new.head()

# %%
dataSansCible
# Out:
#        GCO_IsOuvert  GCO_IsAsv  GCO_IsAssureur  GCO_IsPea  GCO_IsPeaPme  \
# 0                 1          0               1          0           0.0
# 1                 1          0               1          0           0.0
# 2                 1          0               1          0           0.0
# 3                 1          0               1          0           0.0
# 4                 1          0               1          0           0.0
# 5                 1          0               1          0           0.0
# 6                 1          0               1          0           0.0
# 7                 1          0               1          0           0.0
# 8                 1          0               1          0           0.0
# 9                 1          0               1          0           0.0
# 10                1          0               1          0           0.0
# 11                1          0               1          0           0.0
# ...

# %%
#random forest kima arbre decisionnel ama tkharajlek ahsen arbre fil 
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc_model = rfc.fit(X_train, y_train)
y_pred_rfc = rfc_model.predict(X_test)
# Out:
# C:\Users\iheb_\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
y_pred_rfc = rfc_model.predict(new_new)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-a86f37de186b> in <module>
# ----> 1 y_pred_rfc = rfc_model.predict(new_new)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in predict(self, X)
#     543             The predicted classes.
#     544         """
# --> 545         proba = self.predict_proba(X)
#     546
#     547         if self.n_outputs_ == 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in predict_proba(self, X)
#     586         check_is_fitted(self, 'estimators_')
#     587         # Check data
# --> 588         X = self._validate_X_predict(X)
#     589
#     590         # Assign chunk of trees to jobs
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in _validate_X_predict(self, X)
#     357                                  "call `fit` before exploiting the model.")
#     358
# ...

# %%
dataSansCible.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9eba6167718e> in <module>
# ----> 1 dataSansCible.columns
#
# NameError: name 'dataSansCible' is not defined

# %%
print(lastname_info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6fc9f7744aa7> in <module>
# ----> 1 print(lastname_info)
#
# NameError: name 'lastname_info' is not defined

# %%
new_new.drop(['GCO_CodToleranceRisqueMif2'],axis=1,inplace=True)

# %%
print(y_pred_rfc)
# Out:
# [1]

# %% [markdown]
# # Application Random forest sur un nouveau Client

# %%
from tkinter import *

def save_info():




  GCO_IsOuvert_info = GCO_IsOuvert.get()
  GCO_IsOuvert_info = "\n"+"0," + GCO_IsOuvert_info+","


  GCO_IsAsv_info = GCO_IsAsv.get()
  GCO_IsAsv_info = GCO_IsAsv_info +","
    
  GCO_IsAssureur_info = GCO_IsAssureur.get()
  GCO_IsAssureur_info = GCO_IsAssureur_info +","
    
  GCO_IsPea_info = GCO_IsPea.get()
  GCO_IsPea_info = GCO_IsPea_info +","
    
  GCO_IsPeaPme_info = GCO_IsPeaPme.get()
  GCO_IsPeaPme_info = GCO_IsPeaPme_info +","
    
  GCO_CodCapaciteSupportPertesMif2_info = GCO_CodCapaciteSupportPertesMif2.get()
  GCO_CodCapaciteSupportPertesMif2_info = GCO_CodCapaciteSupportPertesMif2_info +","
    
  GCO_CodProfilInvestissementMif2_info = GCO_CodProfilInvestissementMif2.get()
  GCO_CodProfilInvestissementMif2_info = GCO_CodProfilInvestissementMif2_info +","
    
  GCO_CodHorizonPlacementMif2_info = GCO_CodHorizonPlacementMif2.get()
  GCO_CodHorizonPlacementMif2_info = GCO_CodHorizonPlacementMif2_info +","
    
  GCO_CodObjectifPlacementMif2_info = GCO_CodObjectifPlacementMif2.get()
  GCO_CodObjectifPlacementMif2_info = GCO_CodObjectifPlacementMif2_info +","
    
  GCO_CodProfilRisqueMif2_info = GCO_CodProfilRisqueMif2.get()
  GCO_CodProfilRisqueMif2_info = GCO_CodProfilRisqueMif2_info +","
    
  GCO_IsNanti_info = GCO_IsNanti.get()
    



  file = open("user.txt", "a+")
  file.write(GCO_IsOuvert_info)
  file.write(GCO_IsAsv_info)
  file.write(GCO_IsAssureur_info)
  file.write(GCO_IsPea_info)
  file.write(GCO_IsPeaPme_info)
  file.write(GCO_CodCapaciteSupportPertesMif2_info)
  file.write(GCO_CodProfilInvestissementMif2_info)
  file.write(GCO_CodHorizonPlacementMif2_info)
  file.write(GCO_CodObjectifPlacementMif2_info)
  file.write(GCO_CodProfilRisqueMif2_info)
  file.write(GCO_IsNanti_info)

    
  file.close()
  print(" vous avez ajoutez un nouveau client !!!! ")

  #firstname_entry.delete(0, END)
  #lastname_entry.delete(0, END)
 # age_entry.delete(0, END)
  
screen = Tk()
screen.geometry("500x500")
screen.title("Python Form")
heading = Label(text = "Python Form", bg = "grey", fg = "black", width = "500", height = "3")
heading.pack()
 
GCO_IsOuvert_text = Label(text = "GCO_IsOuvert * ",)
GCO_IsAsv_text = Label(text = "GCO_IsAsv * ",)
GCO_IsAssureur_text = Label(text = "GCO_IsAssureur * ",)
GCO_IsPea_text = Label(text = "GCO_IsPea * ",)
GCO_IsPeaPme_text = Label(text = "GCO_IsPeaPme * ",)
GCO_CodCapaciteSupportPertesMif2_text = Label(text = "GCO_CodCapaciteSupportPertesMif2 * ",)
GCO_CodProfilInvestissementMif2_text = Label(text = "GCO_CodProfilInvestissementMif2 * ",)
GCO_CodHorizonPlacementMif2_text = Label(text = "GCO_CodHorizonPlacementMif2 * ",)
GCO_CodObjectifPlacementMif2_text = Label(text = "GCO_CodObjectifPlacementMif2 * ",)
GCO_CodProfilRisqueMif2_text = Label(text = "GCO_CodProfilRisqueMif2 * ",)
GCO_IsNanti_text = Label(text = "GCO_IsNanti * ",)



GCO_IsOuvert_text.place(x = 15, y = 50)
GCO_IsAsv_text.place(x = 15, y = 100)
GCO_IsAssureur_text.place(x = 15, y = 150)
GCO_IsPea_text.place(x = 15, y = 200)
GCO_IsPeaPme_text.place(x = 15, y = 250)
GCO_CodCapaciteSupportPertesMif2_text.place(x = 15, y = 300)
GCO_CodProfilInvestissementMif2_text.place(x = 15, y = 350)
GCO_CodHorizonPlacementMif2_text.place(x = 15, y = 400)
GCO_CodObjectifPlacementMif2_text.place(x = 15, y = 450)
GCO_CodProfilRisqueMif2_text.place(x = 15, y = 500)
GCO_IsNanti_text.place(x = 15, y = 550)



GCO_IsOuvert = StringVar()
GCO_IsAsv = StringVar()
GCO_IsAssureur = StringVar()
GCO_IsPea = StringVar()
GCO_IsPeaPme = StringVar()
GCO_CodCapaciteSupportPertesMif2 = StringVar()
GCO_CodProfilInvestissementMif2 = StringVar()
GCO_CodHorizonPlacementMif2 = StringVar()
GCO_CodObjectifPlacementMif2 = StringVar()
GCO_CodProfilRisqueMif2 = StringVar()
GCO_IsNanti = StringVar()





GCO_IsOuvert_entry = Entry(textvariable = GCO_IsOuvert, width = "30")
GCO_IsAsv_entry = Entry(textvariable = GCO_IsAsv, width = "30")
GCO_IsAssureur_entry = Entry(textvariable = GCO_IsAssureur, width = "30")
GCO_IsPea_entry = Entry(textvariable = GCO_IsPea, width = "30")
GCO_IsPeaPme_entry = Entry(textvariable = GCO_IsPeaPme, width = "30")
GCO_CodCapaciteSupportPertesMif2_entry = Entry(textvariable = GCO_CodCapaciteSupportPertesMif2, width = "30")
GCO_CodProfilInvestissementMif2_entry = Entry(textvariable = GCO_CodProfilInvestissementMif2, width = "30")
GCO_CodHorizonPlacementMif2_entry = Entry(textvariable = GCO_CodHorizonPlacementMif2, width = "30")
GCO_CodObjectifPlacementMif2_entry = Entry(textvariable = GCO_CodObjectifPlacementMif2, width = "30")
GCO_CodProfilRisqueMif2_entry = Entry(textvariable = GCO_CodProfilRisqueMif2, width = "30")
GCO_IsNanti_entry = Entry(textvariable = GCO_IsNanti, width = "30")



GCO_IsOuvert_entry.place(x = 250, y = 50)
GCO_IsAsv_entry.place(x = 250, y = 100)
GCO_IsAssureur_entry.place(x = 250, y = 150)
GCO_IsPea_entry.place(x = 250, y = 200)
GCO_IsPeaPme_entry.place(x = 250, y = 250)
GCO_CodCapaciteSupportPertesMif2_entry.place(x = 250, y = 300)
GCO_CodProfilInvestissementMif2_entry.place(x = 250, y = 350)
GCO_CodHorizonPlacementMif2_entry.place(x = 250, y = 400)
GCO_CodObjectifPlacementMif2_entry.place(x = 250, y = 450)
GCO_CodProfilRisqueMif2_entry.place(x = 250, y = 500)
GCO_IsNanti_entry.place(x = 250, y = 550)



register = Button(screen,text = "Register", width = "30", height = "2", command = save_info, bg = "grey")
register.place(x = 200, y = 600)


# On crée une fenêtre, racine de notre interface
fenetre = Tk()

# On démarre la boucle Tkinter qui s'interompt quand on ferme la fenêtre
fenetre.mainloop()
# Out:
#  vous avez ajoutez un nouveau client !!!!

# %%
# Importation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
new_new = pd.read_table("user.txt",sep=",")
GeneriqueComptes = pd.read_table("GC.txt",sep=",")
GeneriqueComptesNew=GeneriqueComptes
GeneriqueComptesNew['GCO_CodToleranceRisqueMif2'] = np.where(
    GeneriqueComptesNew['GCO_CodToleranceRisqueMif2']>=5, 'Risqué', 'Non-Risqué')
dataCible=GeneriqueComptesNew.iloc[:,8]
dataSansCible=GeneriqueComptesNew
dataSansCible.drop(['Unnamed: 0'],axis=1,inplace=True)
dataSansCible.drop(['GCO_CodToleranceRisqueMif2'],axis=1,inplace=True)
GeneriqueComptes = pd.read_table("GC.txt",sep=",")
GeneriqueComptesNew=GeneriqueComptes
GeneriqueComptesNew['GCO_CodToleranceRisqueMif2'] = np.where(
    GeneriqueComptesNew['GCO_CodToleranceRisqueMif2']>=5, 'Risqué', 'Non-Risqué')
y= pd.factorize(dataCible)[0]
# Out:
# C:\Users\iheb_\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: read_table is deprecated, use read_csv instead.
#
# C:\Users\iheb_\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: read_table is deprecated, use read_csv instead.
#   import sys
# C:\Users\iheb_\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: read_table is deprecated, use read_csv instead.
#   from ipykernel import kernelapp as app

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataSansCible, y,test_size=0.2, random_state=0)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
new_new.drop(['Unnamed: 0'],axis=1,inplace=True)
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc_model = rfc.fit(X_train, y_train)
y_pred_rfc = rfc_model.predict(new_new)
if y_pred_rfc == 1:
  print("Le client est Non-Risqué")
else:
  print("Le client est Risqué")
# Out:
# Le client est Non-Risqué
# C:\Users\iheb_\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
